# %% [markdown]
# <h1>Homework 2</h1>

# %% [markdown]
# #### Bayes' theorem:
# \begin{equation*}
# P(A|B) = \frac{P(B|A)P(A)}{P(B)} \\
# P(A|B): Posteior \\
# P(B|A): Likelihood \\
# P(A): Prior \\
# P(B): Marginal Probability \\
# \end{equation*}

# %% [markdown]
# # Question 1
# ### Read the following example and complete the exercises
#
# You are at the age of 21 and curious about if drinking alcohol would cause liver disease. You contacted a clinic site and got the following information.
#
# 1. Past data tells you that 10% of patients entering the clinic have liver disease (**Prior**).
#
# 2. Five percent of the clinic’s patients are alcoholics (**Marginal Probability**).
#
# 3. Among the patients diagnosed with liver disease, 15% are alcoholics (**Likelihood**).
#
# Now you wonder what is the probability of a patient from the clinic have liver disease given that the patient is alcoholic (**Posterior**)

# %% [markdown]
# ### 1.1
#
# #### If A represents the event of being an alcoholic patient in the clinic and L represents the event of being a patient with liver disease in the clinic, write the bayesian representation (P(A|B)) in the following cells

# %% [markdown]
# Posteria =

# %%
using LaTeXStrings
L"P(L|A) = \frac{P(A|L) \cdot P(L)}{P(A)}"
# Out:
# L"$P(L|A) = \frac{P(A|L) \cdot P(L)}{P(A)}$"

# %% [markdown]
# Prior =

# %%
L"P(L) = 0.10"
# Out:
# L"$P(L) = 0.10$"

# %% [markdown]
# Likelihood =

# %%
L"P(A|L) = \frac{P(L|A) \cdot P(A)}{P(L)}"
# Out:
# L"$P(A|L) = \frac{P(L|A) \cdot P(A)}{P(L)}$"

# %% [markdown]
# Marginal Probability =

# %%
L"P(A) = \sum_{L} P(A|L)P(L) + P(A|\neg L)P(\neg L)"
# Out:
# L"$P(A) = \sum_{L} P(A|L)P(L) + P(A|\neg L)P(\neg L)$"

# %% [markdown]
# ### 1.2
#
# #### Define all the information available and calculate the posterior probability

# %%
P_L = 0.10  # Prior probability of having liver disease
P_A = 0.05  # Marginal probability of being an alcoholic
P_A_given_L = 0.15  # Likelihood of being an alcoholic given liver disease

# Calculate the probability of not having liver disease
P_not_L = 1 - P_L

# Calculate the probability of being an alcoholic given no liver disease
P_A_given_not_L = (P_A - P_A_given_L * P_L) / P_not_L

# Calculate the posterior probability using Bayes' theorem
P_L_given_A = (P_A_given_L * P_L) / P_A

println("The posterior probability P(L|A) is: $(round(P_L_given_A, digits=4))")
# Out:
# The posterior probability P(L|A) is: 0.3

# %% [markdown]
# # Question 2
# ### Read the following example and complete the exercises
# Shown by a <a href="https://pubmed.ncbi.nlm.nih.gov/34242764/#:~:text=The%20overall%20sensitivity%20of%20the,%25%20CI%2024.4%2D65.1">reaserch study</a>, the rapid antigen test for Covid has a sensitivity of 65.3% and a specificity of 99.9%. Assume 1% people have Covid. If randomly select a person and he/she tests positive using the rapid antigen test, what is the probability the person has Covid (posterior).

# %% [markdown]
# ### 2.1
#
# #### The probability of which event is considered marginal probability in this case? Define it in the first cell below and calculate it in the second cell below

# %% [markdown]
# The event is:

# %%
# The event is the probability of testing positive for Covid using the rapid antigen test.

# %% [markdown]
# ### 2.2
#
# #### Define all the information and calculate the probability the randomly selected person has Covid

# %%
P_C = 0.01  # Prior probability of having Covid
P_T_given_C = 0.653  # Sensitivity: Probability of testing positive given having Covid
P_T_given_not_C = 1 - 0.999  # 1 - Specificity: Probability of testing positive given not having Covid

# Calculate the probability of not having Covid
P_not_C = 1 - P_C

# Calculate the marginal probability of testing positive
P_T = P_T_given_C * P_C + P_T_given_not_C * P_not_C

println("The marginal probability P(T) is: $(round(P_T, digits=4))")
# Out:
# The marginal probability P(T) is: 0.0075

# %% [markdown]
# # Question 3
# ### <a href="https://juliastats.org/Distributions.jl/stable/starting/">This page</a> is the documentation for Distribution.jl and complete the exercies

# %% [markdown]
# ### 3.1
#
# #### Randomly draw 1000 samples from a normal distribution with mean = 5 and std = 2

# %%
using Distributions

# Define the normal distribution with mean = 5 and std = 2
dist = Normal(5, 2)

# Draw 1000 samples from the distribution
samples = rand(dist, 1000)

println(samples[1:10])
# Out:
# [0.976633248486027, 4.614060685346221, 8.58855006236203, 4.574694389859729, 4.708348731138433, 6.768541053625246, 3.0214212576148847, 7.60026160295748, 9.825038613011795, 2.8756272685507156]

# %% [markdown]
# ### 3.2
#
# #### Plot  the distribution above in a histogram

# %%
using Plots

histogram(samples, bins=30, title="Histogram of Normal Distribution", xlabel="Value", ylabel="Frequency")

# %% [markdown]
# ### 3.3
#
# #### Plot  the same distribution and change the bins to 50

# %%
histogram(samples, bins=50, title="Histogram of Normal Distribution with 50 Bins", xlabel="Value", ylabel="Frequency")

# %% [markdown]
# ### 3.4
#
# #### Choose a distribution other than normal distribution, Describe what it represents, and draw 1000 samples from the distribution and plot it using parameters of your choice

# %% [markdown]
# Which distribution do you pick:

# %%
# Exponential distribution

# %% [markdown]
# What does the distribution represent?

# %%
# Define the Exponential distribution with rate parameter λ = 1
dist = Exponential(1)

# Draw 1000 samples from the distribution
samples = rand(dist, 1000)

histogram(samples, bins=30, title="Histogram of Exponential Distribution", xlabel="Value", ylabel="Frequency")

# %% [markdown]
# ### 3.5
#
# #### Plot  the two distributions in the same plot

# %%
# Define the Normal distribution with mean = 5 and std = 2
normal_dist = Normal(5, 2)

# Define the Exponential distribution with rate parameter λ = 1
exponential_dist = Exponential(1)

# Draw 1000 samples from each distribution
normal_samples = rand(normal_dist, 1000)
exponential_samples = rand(exponential_dist, 1000)

histogram(normal_samples, bins=30, alpha=0.5, label="Normal Distribution", xlabel="Value", ylabel="Frequency")
histogram!(exponential_samples, bins=30, alpha=0.5, label="Exponential Distribution")

# %% [markdown]
# ### 3.6
#
# #### Draw 10000 samples from the two distributions separately and plot them in the same plot

# %%
# Define the Normal distribution with mean = 5 and std = 2
normal_dist = Normal(5, 2)

# Define the Exponential distribution with rate parameter λ = 1
exponential_dist = Exponential(1)

# Draw 10,000 samples from each distribution
normal_samples = rand(normal_dist, 10000)
exponential_samples = rand(exponential_dist, 10000)

histogram(normal_samples, bins=30, alpha=0.5, label="Normal Distribution", xlabel="Value", ylabel="Frequency")
histogram!(exponential_samples, bins=30, alpha=0.5, label="Exponential Distribution")
